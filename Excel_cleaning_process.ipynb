# %% [markdown]
# # Excel Data Cleaning

# %% [markdown]
# #### Step 1. Import the libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# #### Step 2. Import the 'Raw_Format' excel file

# %%
raw_data = pd.read_excel('Raw_Format.xlsx', header = None)
raw_data
# Out:
#                       0                      1                      2   \
# 0        PT Ikan Terbang    2021-12-01 00:00:00                    NaN
# 1            Window name        Watermark media  Expected/ Played time
# 2   06:00:00 to 05:59:59   IVM_AD_301121_MASTER               08:26:37
# 3                    NaN  IVM_SAN_301121_MASTER               10:07:27
# 4                    NaN   IVM_AD_301121_MASTER               19:11:42
# 5                    NaN  IVM_SAN_301121_MASTER               19:44:09
# 6                    NaN                    NaN                    NaN
# 7        PT Ikan Terbang    2021-12-02 00:00:00                    NaN
# 8            Window name        Watermark media  Expected/ Played time
# 9   06:00:00 to 05:59:59  IVM_SAN_301121_MASTER               09:28:34
# 10                   NaN   IVM_AD_301121_MASTER               09:58:10
# 11                   NaN                    NaN                    NaN
# 12       PT Ikan Terbang    2021-12-03 00:00:00                    NaN
# 13           Window name        Watermark media  Expected/ Played time
# 14  06:00:00 to 05:59:59  IVM_SAN_301121_MASTER               10:32:27
# 15                   NaN   IVM_AD_301121_MASTER               10:41:03
# 16                   NaN                    NaN                    NaN
# 17       PT Ikan Terbang    2021-12-04 00:00:00                    NaN
# 18           Window name        Watermark media  Expected/ Played time
# 19  06:00:00 to 05:59:59   IVM_AD_301121_MASTER               11:55:39
# 20                   NaN  IVM_SAN_301121_MASTER               12:17:10
# 21                   NaN                    NaN                    NaN
# 22       PT Ikan Terbang    2021-12-05 00:00:00                    NaN
# 23           Window name        Watermark media  Expected/ Played time
# 24  06:00:00 to 05:59:59   IVM_AD_301121_MASTER               13:16:15
# 25                   NaN  IVM_SAN_301121_MASTER               13:41:12
# 26                   NaN                    NaN                    NaN
# 27       PT Ikan Terbang    2021-12-06 00:00:00                    NaN
# 28           Window name        Watermark media  Expected/ Played time
# 29                   NaN  IVM_SAN_301121_MASTER               15:24:05
# 30                   NaN   IVM_AD_301121_MASTER               15:46:13
# 31                   NaN                    NaN                    NaN
# 32       PT Ikan Terbang    2021-12-07 00:00:00                    NaN
# 33           Window name        Watermark media  Expected/ Played time
# 34                   NaN  IVM_SAN_301121_MASTER               16:24:59
# 35                   NaN   IVM_AD_301121_MASTER               16:57:56
#
#                       3         4                     5         6          7   \
# 0                    NaN  Semarang              Surabaya     Medan  Palembang
# 1   Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 2            00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 3            00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 4            00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 5            00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 6                    NaN       NaN                   NaN       NaN        NaN
# 7                    NaN  Semarang              Surabaya     Medan  Palembang
# 8   Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 9            00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 10           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 11                   NaN       NaN                   NaN       NaN        NaN
# 12                   NaN  Semarang              Surabaya     Medan  Palembang
# 13  Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 14           00:00:15:00       NaN  WD_021221_EASTJAVAIN       NaN        NaN
# 15           00:00:15:00       NaN  WD_021221_EASTJAVAIN       NaN        NaN
# 16                   NaN       NaN                   NaN       NaN        NaN
# 17                   NaN  Semarang              Surabaya     Medan  Palembang
# 18  Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 19           00:00:15:00       NaN  WD_031221_EASTJAVAIN       NaN        NaN
# 20           00:00:15:00       NaN  WD_031221_EASTJAVAIN       NaN        NaN
# 21                   NaN       NaN                   NaN       NaN        NaN
# 22                   NaN  Semarang              Surabaya     Medan  Palembang
# 23  Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 24           00:00:15:00       NaN  WD_031221_EASTJAVAIN       NaN        NaN
# 25           00:00:15:00       NaN  WD_031221_EASTJAVAIN       NaN        NaN
# 26                   NaN       NaN                   NaN       NaN        NaN
# 27                   NaN  Semarang              Surabaya     Medan  Palembang
# 28  Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 29           00:00:15:00       NaN  WD_031221_EASTJAVAIN       NaN        NaN
# 30           00:00:15:00       NaN  WD_031221_EASTJAVAIN       NaN        NaN
# 31                   NaN       NaN                   NaN       NaN        NaN
# 32                   NaN  Semarang              Surabaya     Medan  Palembang
# 33  Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 34           00:00:15:00       NaN  WD_031221_EASTJAVAIN       NaN        NaN
# 35           00:00:15:00       NaN  WD_031221_EASTJAVAIN       NaN        NaN
#
#                         8                     9                     10  \
# 0              Banjarmasin              Makassar              Denpasar
# 1                  Id Aset               Id Aset               Id Aset
# 2   WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 3   WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 4   WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 5   WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 6                      NaN                   NaN                   NaN
# 7              Banjarmasin              Makassar              Denpasar
# 8                  Id Aset               Id Aset               Id Aset
# 9   WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 10  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 11                     NaN                   NaN                   NaN
# 12             Banjarmasin              Makassar              Denpasar
# 13                 Id Aset               Id Aset               Id Aset
# 14  WD_021221_KALIMANTANIN  WD_021221_SULAWESIIN  WD_021221_DENPASARIN
# 15  WD_021221_KALIMANTANIN  WD_021221_SULAWESIIN  WD_021221_DENPASARIN
# 16                     NaN                   NaN                   NaN
# 17             Banjarmasin              Makassar              Denpasar
# 18                 Id Aset               Id Aset               Id Aset
# 19  WD_031221_KALIMANTANIN  WD_031221_SULAWESIIN  WD_031221_DENPASARIN
# 20  WD_031221_KALIMANTANIN  WD_031221_SULAWESIIN  WD_031221_DENPASARIN
# 21                     NaN                   NaN                   NaN
# 22             Banjarmasin              Makassar              Denpasar
# 23                 Id Aset               Id Aset               Id Aset
# 24  WD_031221_KALIMANTANIN  WD_031221_SULAWESIIN  WD_031221_DENPASARIN
# 25  WD_031221_KALIMANTANIN  WD_031221_SULAWESIIN  WD_031221_DENPASARIN
# 26                     NaN                   NaN                   NaN
# 27             Banjarmasin              Makassar              Denpasar
# 28                 Id Aset               Id Aset               Id Aset
# 29  WD_031221_KALIMANTANIN  WD_031221_SULAWESIIN  WD_031221_DENPASARIN
# 30  WD_031221_KALIMANTANIN  WD_031221_SULAWESIIN  WD_031221_DENPASARIN
# 31                     NaN                   NaN                   NaN
# 32             Banjarmasin              Makassar              Denpasar
# 33                 Id Aset               Id Aset               Id Aset
# 34  WD_031221_KALIMANTANIN  WD_031221_SULAWESIIN  WD_031221_DENPASARIN
# 35  WD_031221_KALIMANTANIN  WD_031221_SULAWESIIN  WD_031221_DENPASARIN
#
#           11
# 0    Bandung
# 1    Id Aset
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7    Bandung
# 8    Id Aset
# 9        NaN
# 10       NaN
# 11       NaN
# 12   Bandung
# 13   Id Aset
# 14       NaN
# 15       NaN
# 16       NaN
# 17   Bandung
# 18   Id Aset
# 19       NaN
# 20       NaN
# 21       NaN
# 22   Bandung
# 23   Id Aset
# 24       NaN
# 25       NaN
# 26       NaN
# 27   Bandung
# 28   Id Aset
# 29       NaN
# 30       NaN
# 31       NaN
# 32   Bandung
# 33   Id Aset
# 34       NaN
# 35       NaN

# %% [markdown]
# From here, we can see the raw data consists of multiple tables separated by empty lines

# %% [markdown]
# #### Step 3. Start cleaning the first table from the raw data

# %%
# We can get the first table using this code

first_table = raw_data.iloc[:7]
first_table
# Out:
#                      0                      1                      2   \
# 0       PT Ikan Terbang    2021-12-01 00:00:00                    NaN
# 1           Window name        Watermark media  Expected/ Played time
# 2  06:00:00 to 05:59:59   IVM_AD_301121_MASTER               08:26:37
# 3                   NaN  IVM_SAN_301121_MASTER               10:07:27
# 4                   NaN   IVM_AD_301121_MASTER               19:11:42
# 5                   NaN  IVM_SAN_301121_MASTER               19:44:09
# 6                   NaN                    NaN                    NaN
#
#                      3         4                     5         6          7   \
# 0                   NaN  Semarang              Surabaya     Medan  Palembang
# 1  Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 2           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 3           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 4           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 5           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 6                   NaN       NaN                   NaN       NaN        NaN
#
#                        8                     9                     10  \
# 0             Banjarmasin              Makassar              Denpasar
# 1                 Id Aset               Id Aset               Id Aset
# 2  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 3  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 4  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 5  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 6                     NaN                   NaN                   NaN
#
#          11
# 0   Bandung
# 1   Id Aset
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN

# %%
# We can see there's an empty line at the bottom of the table
# First we need to remove the empty line using this code

first_table = first_table.dropna(how= 'all', axis = 0)
first_table
# Out:
#                      0                      1                      2   \
# 0       PT Ikan Terbang    2021-12-01 00:00:00                    NaN
# 1           Window name        Watermark media  Expected/ Played time
# 2  06:00:00 to 05:59:59   IVM_AD_301121_MASTER               08:26:37
# 3                   NaN  IVM_SAN_301121_MASTER               10:07:27
# 4                   NaN   IVM_AD_301121_MASTER               19:11:42
# 5                   NaN  IVM_SAN_301121_MASTER               19:44:09
#
#                      3         4                     5         6          7   \
# 0                   NaN  Semarang              Surabaya     Medan  Palembang
# 1  Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 2           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 3           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 4           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 5           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
#
#                        8                     9                     10  \
# 0             Banjarmasin              Makassar              Denpasar
# 1                 Id Aset               Id Aset               Id Aset
# 2  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 3  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 4  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 5  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
#
#          11
# 0   Bandung
# 1   Id Aset
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN

# %%
# To make it easier to read, we can separate the table into 2 parts
# the first one consists of 'Window name', 'Watermark media', 'Expected/Played time', and 'Replacement Duration'

df_1 = first_table.iloc[:,:4]
df_1
# Out:
#                       0                      1                      2  \
# 0       PT Ikan Terbang    2021-12-01 00:00:00                    NaN
# 1           Window name        Watermark media  Expected/ Played time
# 2  06:00:00 to 05:59:59   IVM_AD_301121_MASTER               08:26:37
# 3                   NaN  IVM_SAN_301121_MASTER               10:07:27
# 4                   NaN   IVM_AD_301121_MASTER               19:11:42
# 5                   NaN  IVM_SAN_301121_MASTER               19:44:09
#
#                       3
# 0                   NaN
# 1  Replacement Duration
# 2           00:00:15:00
# 3           00:00:15:00
# 4           00:00:15:00
# 5           00:00:15:00

# %%
# the second one consists of 'City' and 'Id Aset'

df_2 = first_table.iloc[:,4:]
df_2
# Out:
#          4                     5         6          7   \
# 0  Semarang              Surabaya     Medan  Palembang
# 1   Id Aset               Id Aset   Id Aset    Id Aset
# 2       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 3       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 4       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 5       NaN  WD_011221_EASTJAVAIN       NaN        NaN
#
#                        8                     9                     10  \
# 0             Banjarmasin              Makassar              Denpasar
# 1                 Id Aset               Id Aset               Id Aset
# 2  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 3  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 4  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 5  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
#
#          11
# 0   Bandung
# 1   Id Aset
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN

# %%
# Now, we can make a new table using our desired format

# Make a new table
df_new = pd.DataFrame()

for i in range(df_2.shape[1]):      # We use df_2.shape[1] to count how many cities we have
    city = df_2.iloc[0, i]          # then, we use this code to get the city name
    
    for j in range(len(df_1)-2):    # we use len(df_1)-2 to get the length of our data
        
        # We make new variables to fill our table rows
        idAset = df_2.iloc[2+j, i]
        winName = df_1.iloc[2,0]
        watMedia = df_1.iloc[2+j,1]
        expTime = df_1.iloc[2+j,2]
        repDuration = df_1.iloc[2+j,3]

        # Make a new table 'row' using the clean format
        row = pd.DataFrame([[city, idAset, winName, watMedia, expTime, repDuration]], 
                            columns=['City', 'Id Aset', 'Window name', 'Watermark media', 
                                        'Expected/ Played time', 'Replacement Duration'])
        

        # concat the 'row' to our df_new table
        df_new = pd.concat([df_new, row], ignore_index= True)

# Then, we can add the 'Date' and 'Company' columns to the table
df_new['Date'] = first_table.iloc[0,1].strftime('%Y-%m-%d %H:%M:%S')
df_new['Company'] = first_table.iloc[0,0]

df_new
# Out:
#            City                 Id Aset           Window name  \
# 0      Semarang                     NaN  06:00:00 to 05:59:59
# 1      Semarang                     NaN  06:00:00 to 05:59:59
# 2      Semarang                     NaN  06:00:00 to 05:59:59
# 3      Semarang                     NaN  06:00:00 to 05:59:59
# 4      Surabaya    WD_011221_EASTJAVAIN  06:00:00 to 05:59:59
# 5      Surabaya    WD_011221_EASTJAVAIN  06:00:00 to 05:59:59
# 6      Surabaya    WD_011221_EASTJAVAIN  06:00:00 to 05:59:59
# 7      Surabaya    WD_011221_EASTJAVAIN  06:00:00 to 05:59:59
# 8         Medan                     NaN  06:00:00 to 05:59:59
# 9         Medan                     NaN  06:00:00 to 05:59:59
# 10        Medan                     NaN  06:00:00 to 05:59:59
# 11        Medan                     NaN  06:00:00 to 05:59:59
# 12    Palembang                     NaN  06:00:00 to 05:59:59
# 13    Palembang                     NaN  06:00:00 to 05:59:59
# 14    Palembang                     NaN  06:00:00 to 05:59:59
# 15    Palembang                     NaN  06:00:00 to 05:59:59
# 16  Banjarmasin  WD_011221_KALIMANTANIN  06:00:00 to 05:59:59
# 17  Banjarmasin  WD_011221_KALIMANTANIN  06:00:00 to 05:59:59
# 18  Banjarmasin  WD_011221_KALIMANTANIN  06:00:00 to 05:59:59
# 19  Banjarmasin  WD_011221_KALIMANTANIN  06:00:00 to 05:59:59
# 20     Makassar    WD_011221_SULAWESIIN  06:00:00 to 05:59:59
# 21     Makassar    WD_011221_SULAWESIIN  06:00:00 to 05:59:59
# 22     Makassar    WD_011221_SULAWESIIN  06:00:00 to 05:59:59
# 23     Makassar    WD_011221_SULAWESIIN  06:00:00 to 05:59:59
# 24     Denpasar    WD_011221_DENPASARIN  06:00:00 to 05:59:59
# 25     Denpasar    WD_011221_DENPASARIN  06:00:00 to 05:59:59
# 26     Denpasar    WD_011221_DENPASARIN  06:00:00 to 05:59:59
# 27     Denpasar    WD_011221_DENPASARIN  06:00:00 to 05:59:59
# 28      Bandung                     NaN  06:00:00 to 05:59:59
# 29      Bandung                     NaN  06:00:00 to 05:59:59
# 30      Bandung                     NaN  06:00:00 to 05:59:59
# 31      Bandung                     NaN  06:00:00 to 05:59:59
#
#           Watermark media Expected/ Played time Replacement Duration  \
# 0    IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 1   IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 2    IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 3   IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 4    IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 5   IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 6    IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 7   IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 8    IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 9   IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 10   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 11  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 12   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 13  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 14   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 15  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 16   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 17  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 18   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 19  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 20   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 21  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 22   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 23  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 24   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 25  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 26   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 27  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 28   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 29  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 30   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 31  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
#
#                    Date          Company
# 0   2021-12-01 00:00:00  PT Ikan Terbang
# 1   2021-12-01 00:00:00  PT Ikan Terbang
# 2   2021-12-01 00:00:00  PT Ikan Terbang
# 3   2021-12-01 00:00:00  PT Ikan Terbang
# 4   2021-12-01 00:00:00  PT Ikan Terbang
# 5   2021-12-01 00:00:00  PT Ikan Terbang
# 6   2021-12-01 00:00:00  PT Ikan Terbang
# 7   2021-12-01 00:00:00  PT Ikan Terbang
# 8   2021-12-01 00:00:00  PT Ikan Terbang
# 9   2021-12-01 00:00:00  PT Ikan Terbang
# 10  2021-12-01 00:00:00  PT Ikan Terbang
# 11  2021-12-01 00:00:00  PT Ikan Terbang
# 12  2021-12-01 00:00:00  PT Ikan Terbang
# 13  2021-12-01 00:00:00  PT Ikan Terbang
# 14  2021-12-01 00:00:00  PT Ikan Terbang
# 15  2021-12-01 00:00:00  PT Ikan Terbang
# 16  2021-12-01 00:00:00  PT Ikan Terbang
# 17  2021-12-01 00:00:00  PT Ikan Terbang
# 18  2021-12-01 00:00:00  PT Ikan Terbang
# 19  2021-12-01 00:00:00  PT Ikan Terbang
# 20  2021-12-01 00:00:00  PT Ikan Terbang
# 21  2021-12-01 00:00:00  PT Ikan Terbang
# 22  2021-12-01 00:00:00  PT Ikan Terbang
# 23  2021-12-01 00:00:00  PT Ikan Terbang
# 24  2021-12-01 00:00:00  PT Ikan Terbang
# 25  2021-12-01 00:00:00  PT Ikan Terbang
# 26  2021-12-01 00:00:00  PT Ikan Terbang
# 27  2021-12-01 00:00:00  PT Ikan Terbang
# 28  2021-12-01 00:00:00  PT Ikan Terbang
# 29  2021-12-01 00:00:00  PT Ikan Terbang
# 30  2021-12-01 00:00:00  PT Ikan Terbang
# 31  2021-12-01 00:00:00  PT Ikan Terbang

# %%
#To summarize all the steps, we define a function to clean the table 

def cleanTable(df):
    df = df.dropna(how= 'all', axis = 0)

    df_1 = df.iloc[:,:4]
    df_2 = df.iloc[:,4:]

    df_new = pd.DataFrame()

    for i in range(df_2.shape[1]):
        city = df_2.iloc[0, i]
        
        for j in range(len(df_1)-2):
            
            idAset = df_2.iloc[2+j, i]
            winName = df_1.iloc[2,0]
            watMedia = df_1.iloc[2+j,1]
            expTime = df_1.iloc[2+j,2]
            repDuration = df_1.iloc[2+j,3]

            row = pd.DataFrame([[city, idAset, winName, watMedia, expTime, repDuration]], 
                                columns=['City', 'Id Aset', 'Window name', 'Watermark media', 
                                            'Expected/ Played time', 'Replacement Duration'])
           
            df_new = pd.concat([df_new, row], ignore_index= True)

    df_new['Date'] = df.iloc[0,1].strftime('%Y-%m-%d %H:%M:%S')
    df_new['Company'] = df.iloc[0,0]

    return df_new

# %%
# Now, we can clean the table with a single line of code

cleanTable(first_table)
# Out:
#            City                 Id Aset           Window name  \
# 0      Semarang                     NaN  06:00:00 to 05:59:59
# 1      Semarang                     NaN  06:00:00 to 05:59:59
# 2      Semarang                     NaN  06:00:00 to 05:59:59
# 3      Semarang                     NaN  06:00:00 to 05:59:59
# 4      Surabaya    WD_011221_EASTJAVAIN  06:00:00 to 05:59:59
# 5      Surabaya    WD_011221_EASTJAVAIN  06:00:00 to 05:59:59
# 6      Surabaya    WD_011221_EASTJAVAIN  06:00:00 to 05:59:59
# 7      Surabaya    WD_011221_EASTJAVAIN  06:00:00 to 05:59:59
# 8         Medan                     NaN  06:00:00 to 05:59:59
# 9         Medan                     NaN  06:00:00 to 05:59:59
# 10        Medan                     NaN  06:00:00 to 05:59:59
# 11        Medan                     NaN  06:00:00 to 05:59:59
# 12    Palembang                     NaN  06:00:00 to 05:59:59
# 13    Palembang                     NaN  06:00:00 to 05:59:59
# 14    Palembang                     NaN  06:00:00 to 05:59:59
# 15    Palembang                     NaN  06:00:00 to 05:59:59
# 16  Banjarmasin  WD_011221_KALIMANTANIN  06:00:00 to 05:59:59
# 17  Banjarmasin  WD_011221_KALIMANTANIN  06:00:00 to 05:59:59
# 18  Banjarmasin  WD_011221_KALIMANTANIN  06:00:00 to 05:59:59
# 19  Banjarmasin  WD_011221_KALIMANTANIN  06:00:00 to 05:59:59
# 20     Makassar    WD_011221_SULAWESIIN  06:00:00 to 05:59:59
# 21     Makassar    WD_011221_SULAWESIIN  06:00:00 to 05:59:59
# 22     Makassar    WD_011221_SULAWESIIN  06:00:00 to 05:59:59
# 23     Makassar    WD_011221_SULAWESIIN  06:00:00 to 05:59:59
# 24     Denpasar    WD_011221_DENPASARIN  06:00:00 to 05:59:59
# 25     Denpasar    WD_011221_DENPASARIN  06:00:00 to 05:59:59
# 26     Denpasar    WD_011221_DENPASARIN  06:00:00 to 05:59:59
# 27     Denpasar    WD_011221_DENPASARIN  06:00:00 to 05:59:59
# 28      Bandung                     NaN  06:00:00 to 05:59:59
# 29      Bandung                     NaN  06:00:00 to 05:59:59
# 30      Bandung                     NaN  06:00:00 to 05:59:59
# 31      Bandung                     NaN  06:00:00 to 05:59:59
#
#           Watermark media Expected/ Played time Replacement Duration  \
# 0    IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 1   IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 2    IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 3   IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 4    IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 5   IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 6    IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 7   IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 8    IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 9   IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 10   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 11  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 12   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 13  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 14   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 15  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 16   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 17  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 18   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 19  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 20   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 21  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 22   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 23  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 24   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 25  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 26   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 27  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 28   IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 29  IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 30   IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 31  IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
#
#                    Date          Company
# 0   2021-12-01 00:00:00  PT Ikan Terbang
# 1   2021-12-01 00:00:00  PT Ikan Terbang
# 2   2021-12-01 00:00:00  PT Ikan Terbang
# 3   2021-12-01 00:00:00  PT Ikan Terbang
# 4   2021-12-01 00:00:00  PT Ikan Terbang
# 5   2021-12-01 00:00:00  PT Ikan Terbang
# 6   2021-12-01 00:00:00  PT Ikan Terbang
# 7   2021-12-01 00:00:00  PT Ikan Terbang
# 8   2021-12-01 00:00:00  PT Ikan Terbang
# 9   2021-12-01 00:00:00  PT Ikan Terbang
# 10  2021-12-01 00:00:00  PT Ikan Terbang
# 11  2021-12-01 00:00:00  PT Ikan Terbang
# 12  2021-12-01 00:00:00  PT Ikan Terbang
# 13  2021-12-01 00:00:00  PT Ikan Terbang
# 14  2021-12-01 00:00:00  PT Ikan Terbang
# 15  2021-12-01 00:00:00  PT Ikan Terbang
# 16  2021-12-01 00:00:00  PT Ikan Terbang
# 17  2021-12-01 00:00:00  PT Ikan Terbang
# 18  2021-12-01 00:00:00  PT Ikan Terbang
# 19  2021-12-01 00:00:00  PT Ikan Terbang
# 20  2021-12-01 00:00:00  PT Ikan Terbang
# 21  2021-12-01 00:00:00  PT Ikan Terbang
# 22  2021-12-01 00:00:00  PT Ikan Terbang
# 23  2021-12-01 00:00:00  PT Ikan Terbang
# 24  2021-12-01 00:00:00  PT Ikan Terbang
# 25  2021-12-01 00:00:00  PT Ikan Terbang
# 26  2021-12-01 00:00:00  PT Ikan Terbang
# 27  2021-12-01 00:00:00  PT Ikan Terbang
# 28  2021-12-01 00:00:00  PT Ikan Terbang
# 29  2021-12-01 00:00:00  PT Ikan Terbang
# 30  2021-12-01 00:00:00  PT Ikan Terbang
# 31  2021-12-01 00:00:00  PT Ikan Terbang

# %% [markdown]
# #### Step 4. Separate the Raw Data into multiple tables

# %%
# We can split a table into multiple tables using the np.split() function

# We use the empty lines as our guide to split the table
split_data = np.split(raw_data, raw_data[raw_data.isnull().all(1)].index) 

# We can check how many tables we have using the len() function
len(split_data)
# Out:
# 7

# %%
# To access the tables, we can use indexing (starting from index 0)
split_data[1]
# Out:
#                       0                      1                      2   \
# 6                    NaN                    NaN                    NaN
# 7        PT Ikan Terbang    2021-12-02 00:00:00                    NaN
# 8            Window name        Watermark media  Expected/ Played time
# 9   06:00:00 to 05:59:59  IVM_SAN_301121_MASTER               09:28:34
# 10                   NaN   IVM_AD_301121_MASTER               09:58:10
#
#                       3         4                     5         6          7   \
# 6                    NaN       NaN                   NaN       NaN        NaN
# 7                    NaN  Semarang              Surabaya     Medan  Palembang
# 8   Replacement Duration   Id Aset               Id Aset   Id Aset    Id Aset
# 9            00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
# 10           00:00:15:00       NaN  WD_011221_EASTJAVAIN       NaN        NaN
#
#                         8                     9                     10  \
# 6                      NaN                   NaN                   NaN
# 7              Banjarmasin              Makassar              Denpasar
# 8                  Id Aset               Id Aset               Id Aset
# 9   WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
# 10  WD_011221_KALIMANTANIN  WD_011221_SULAWESIIN  WD_011221_DENPASARIN
#
#           11
# 6        NaN
# 7    Bandung
# 8    Id Aset
# 9        NaN
# 10       NaN

# %%
# Next, we define a function to fully clean the raw data into the clean format

def full_cleaned(raw_data):

    # first we split the tables like we did before
    split_data = np.split(raw_data, raw_data[raw_data.isnull().all(1)].index) 

    # make a new table
    cleaned_table = pd.DataFrame()

    # we access each tables in split_data and clean them using the cleanTable() function we made
    for i in range(len(split_data)):
        data = pd.DataFrame(split_data[i])
        
        # concat the separate tables into our cleaned_table
        cleaned_table = pd.concat([cleaned_table, cleanTable(data)], ignore_index= True)
        
    return cleaned_table

# %%
# Finally, we can clean the raw data using a single function

df = full_cleaned(raw_data)

df
# Out:
#          City               Id Aset           Window name  \
# 0    Semarang                   NaN  06:00:00 to 05:59:59
# 1    Semarang                   NaN  06:00:00 to 05:59:59
# 2    Semarang                   NaN  06:00:00 to 05:59:59
# 3    Semarang                   NaN  06:00:00 to 05:59:59
# 4    Surabaya  WD_011221_EASTJAVAIN  06:00:00 to 05:59:59
# ..        ...                   ...                   ...
# 123  Makassar  WD_031221_SULAWESIIN                   NaN
# 124  Denpasar  WD_031221_DENPASARIN                   NaN
# 125  Denpasar  WD_031221_DENPASARIN                   NaN
# 126   Bandung                   NaN                   NaN
# 127   Bandung                   NaN                   NaN
#
#            Watermark media Expected/ Played time Replacement Duration  \
# 0     IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# 1    IVM_SAN_301121_MASTER              10:07:27          00:00:15:00
# 2     IVM_AD_301121_MASTER              19:11:42          00:00:15:00
# 3    IVM_SAN_301121_MASTER              19:44:09          00:00:15:00
# 4     IVM_AD_301121_MASTER              08:26:37          00:00:15:00
# ..                     ...                   ...                  ...
# 123   IVM_AD_301121_MASTER              16:57:56          00:00:15:00
# 124  IVM_SAN_301121_MASTER              16:24:59          00:00:15:00
# 125   IVM_AD_301121_MASTER              16:57:56          00:00:15:00
# 126  IVM_SAN_301121_MASTER              16:24:59          00:00:15:00
# 127   IVM_AD_301121_MASTER              16:57:56          00:00:15:00
#
#                     Date          Company
# 0    2021-12-01 00:00:00  PT Ikan Terbang
# 1    2021-12-01 00:00:00  PT Ikan Terbang
# 2    2021-12-01 00:00:00  PT Ikan Terbang
# 3    2021-12-01 00:00:00  PT Ikan Terbang
# 4    2021-12-01 00:00:00  PT Ikan Terbang
# ..                   ...              ...
# 123  2021-12-07 00:00:00  PT Ikan Terbang
# 124  2021-12-07 00:00:00  PT Ikan Terbang
# 125  2021-12-07 00:00:00  PT Ikan Terbang
# 126  2021-12-07 00:00:00  PT Ikan Terbang
# 127  2021-12-07 00:00:00  PT Ikan Terbang
#
# [128 rows x 8 columns]

# %% [markdown]
# #### Step 5. Export the table into Excel file

# %%
df.to_excel('Clean_Format.xlsx', index = False)
